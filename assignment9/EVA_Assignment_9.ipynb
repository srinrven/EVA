# %% [markdown]
# **Conclusions** :
#
#
#
#
# *   With cutout validation accuracy improved 1.24 %, from 88.77% to 90.01%
# *   Grad CAM highlighted in many images the important areas for the classes that are being predicted.
# *   After cutout the are of importance has moved from irrelevant positions to more relevant positions.

# %%
from keras import backend as K
import keras.models
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %%
from google.colab import drive
drive.mount('../content/drive/', force_remount=True)
# Out:
# Mounted at ../content/drive/

# %%
import os
os.listdir('../content/drive/My Drive/EVA/')
# Out:
# ['Architectural Basics.md']

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# 6B model - This is to get base accuracy before cutout
# Define the model
model1 = Sequential()
model1.add(Convolution2D(32, 3, 3, border_mode='same',kernel_regularizer=regularizers.l2(0.0001), input_shape=(32, 32, 3)))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.2))

model1.add(Convolution2D(32, 1, 1))

model1.add(Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.3))

model1.add(Convolution2D(32, 1, 1))

model1.add(Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(256, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.5))

model1.add(Convolution2D(10, 1, 1))

model1.add(AveragePooling2D(pool_size = (4,4)))
model1.add(Flatten())

model1.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# W0706 03:06:04.012564 140132969863040 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau

checkpointer = ModelCheckpoint(filepath='../content/drive/My Drive/EVA/model_before_cutout.h5', monitor='val_acc', mode='auto', verbose = 1, save_best_only=True)
lr_reducer = ReduceLROnPlateau(monitor='val_acc',factor=0.8, cooldown=0, patience=5, min_lr=0.5e-9,verbose = 1)



# Compile the model
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_58 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_43 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_44 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_45 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_46 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 8, 8, 32)          4128
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 8, 8, 128)         36992
# _________________________________________________________________
# activation_47 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_48 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 4, 4, 10)          2570
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_49 (Activation)   (None, 10)                0
# =================================================================
# Total params: 455,370
# Trainable params: 454,026
# Non-trainable params: 1,344
# _________________________________________________________________

# %% [markdown]
# **Model without Cutout**

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model1.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), callbacks=[checkpointer,lr_reducer],verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 17s 42ms/step - loss: 1.3729 - acc: 0.5236 - val_loss: 1.1786 - val_acc: 0.6122
#
# Epoch 00001: val_acc improved from -inf to 0.61220, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 2/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.9562 - acc: 0.6809 - val_loss: 1.0026 - val_acc: 0.6684
#
# Epoch 00002: val_acc improved from 0.61220 to 0.66840, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 3/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.7968 - acc: 0.7407 - val_loss: 0.7729 - val_acc: 0.7507
#
# Epoch 00003: val_acc improved from 0.66840 to 0.75070, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 4/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.7059 - acc: 0.7733 - val_loss: 0.7680 - val_acc: 0.7572
#
# Epoch 00004: val_acc improved from 0.75070 to 0.75720, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 5/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.6412 - acc: 0.8009 - val_loss: 0.6460 - val_acc: 0.8018
#
# Epoch 00005: val_acc improved from 0.75720 to 0.80180, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 6/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.5969 - acc: 0.8171 - val_loss: 0.7183 - val_acc: 0.7800
#
# Epoch 00006: val_acc did not improve from 0.80180
# Epoch 7/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.5597 - acc: 0.8315 - val_loss: 0.7846 - val_acc: 0.7605
#
# Epoch 00007: val_acc did not improve from 0.80180
# Epoch 8/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.5344 - acc: 0.8420 - val_loss: 0.6508 - val_acc: 0.8117
#
# Epoch 00008: val_acc improved from 0.80180 to 0.81170, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 9/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.5135 - acc: 0.8541 - val_loss: 0.7778 - val_acc: 0.7851
#
# Epoch 00009: val_acc did not improve from 0.81170
# Epoch 10/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4958 - acc: 0.8619 - val_loss: 0.6034 - val_acc: 0.8334
#
# Epoch 00010: val_acc improved from 0.81170 to 0.83340, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 11/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4800 - acc: 0.8695 - val_loss: 0.7141 - val_acc: 0.8031
#
# Epoch 00011: val_acc did not improve from 0.83340
# Epoch 12/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4696 - acc: 0.8749 - val_loss: 0.6606 - val_acc: 0.8234
#
# Epoch 00012: val_acc did not improve from 0.83340
# Epoch 13/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4582 - acc: 0.8820 - val_loss: 0.6263 - val_acc: 0.8331
#
# Epoch 00013: val_acc did not improve from 0.83340
# Epoch 14/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4460 - acc: 0.8883 - val_loss: 0.6989 - val_acc: 0.8193
#
# Epoch 00014: val_acc did not improve from 0.83340
# Epoch 15/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4459 - acc: 0.8884 - val_loss: 0.7075 - val_acc: 0.8127
#
# Epoch 00015: val_acc did not improve from 0.83340
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 16/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.4006 - acc: 0.9044 - val_loss: 0.5920 - val_acc: 0.8501
#
# Epoch 00016: val_acc improved from 0.83340 to 0.85010, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 17/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3859 - acc: 0.9104 - val_loss: 0.6451 - val_acc: 0.8419
#
# Epoch 00017: val_acc did not improve from 0.85010
# Epoch 18/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3805 - acc: 0.9140 - val_loss: 0.7063 - val_acc: 0.8283
#
# Epoch 00018: val_acc did not improve from 0.85010
# Epoch 19/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3758 - acc: 0.9146 - val_loss: 0.5889 - val_acc: 0.8565
#
# Epoch 00019: val_acc improved from 0.85010 to 0.85650, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 20/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3722 - acc: 0.9165 - val_loss: 0.6898 - val_acc: 0.8307
#
# Epoch 00020: val_acc did not improve from 0.85650
# Epoch 21/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3660 - acc: 0.9185 - val_loss: 0.7620 - val_acc: 0.8184
#
# Epoch 00021: val_acc did not improve from 0.85650
# Epoch 22/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3577 - acc: 0.9234 - val_loss: 0.6549 - val_acc: 0.8454
#
# Epoch 00022: val_acc did not improve from 0.85650
# Epoch 23/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3571 - acc: 0.9242 - val_loss: 0.6050 - val_acc: 0.8571
#
# Epoch 00023: val_acc improved from 0.85650 to 0.85710, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 24/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3541 - acc: 0.9251 - val_loss: 0.6348 - val_acc: 0.8546
#
# Epoch 00024: val_acc did not improve from 0.85710
# Epoch 25/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3511 - acc: 0.9268 - val_loss: 0.6498 - val_acc: 0.8549
#
# Epoch 00025: val_acc did not improve from 0.85710
# Epoch 26/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.3482 - acc: 0.9294 - val_loss: 0.6240 - val_acc: 0.8601
#
# Epoch 00026: val_acc improved from 0.85710 to 0.86010, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 27/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3382 - acc: 0.9330 - val_loss: 0.6694 - val_acc: 0.8427
#
# Epoch 00027: val_acc did not improve from 0.86010
# Epoch 28/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3475 - acc: 0.9294 - val_loss: 0.6318 - val_acc: 0.8574
#
# Epoch 00028: val_acc did not improve from 0.86010
# Epoch 29/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3420 - acc: 0.9334 - val_loss: 0.6766 - val_acc: 0.8473
#
# Epoch 00029: val_acc did not improve from 0.86010
# Epoch 30/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3363 - acc: 0.9350 - val_loss: 0.6514 - val_acc: 0.8546
#
# Epoch 00030: val_acc did not improve from 0.86010
# Epoch 31/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3365 - acc: 0.9352 - val_loss: 0.6381 - val_acc: 0.8622
#
# Epoch 00031: val_acc improved from 0.86010 to 0.86220, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 32/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3377 - acc: 0.9349 - val_loss: 0.7060 - val_acc: 0.8430
#
# Epoch 00032: val_acc did not improve from 0.86220
# Epoch 33/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3289 - acc: 0.9388 - val_loss: 0.6660 - val_acc: 0.8546
#
# Epoch 00033: val_acc did not improve from 0.86220
# Epoch 34/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3327 - acc: 0.9387 - val_loss: 0.6385 - val_acc: 0.8584
#
# Epoch 00034: val_acc did not improve from 0.86220
# Epoch 35/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3282 - acc: 0.9383 - val_loss: 0.6763 - val_acc: 0.8435
#
# Epoch 00035: val_acc did not improve from 0.86220
# Epoch 36/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3286 - acc: 0.9405 - val_loss: 0.7142 - val_acc: 0.8472
#
# Epoch 00036: val_acc did not improve from 0.86220
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 37/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.3013 - acc: 0.9499 - val_loss: 0.6429 - val_acc: 0.8611
#
# Epoch 00037: val_acc did not improve from 0.86220
# Epoch 38/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2940 - acc: 0.9542 - val_loss: 0.6545 - val_acc: 0.8613
#
# Epoch 00038: val_acc did not improve from 0.86220
# Epoch 39/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2962 - acc: 0.9513 - val_loss: 0.7180 - val_acc: 0.8493
#
# Epoch 00039: val_acc did not improve from 0.86220
# Epoch 40/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2928 - acc: 0.9528 - val_loss: 0.7139 - val_acc: 0.8496
#
# Epoch 00040: val_acc did not improve from 0.86220
# Epoch 41/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2888 - acc: 0.9523 - val_loss: 0.6325 - val_acc: 0.8650
#
# Epoch 00041: val_acc improved from 0.86220 to 0.86500, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 42/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2829 - acc: 0.9552 - val_loss: 0.6967 - val_acc: 0.8560
#
# Epoch 00042: val_acc did not improve from 0.86500
# Epoch 43/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2838 - acc: 0.9530 - val_loss: 0.6623 - val_acc: 0.8599
#
# Epoch 00043: val_acc did not improve from 0.86500
# Epoch 44/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2867 - acc: 0.9543 - val_loss: 0.6487 - val_acc: 0.8665
#
# Epoch 00044: val_acc improved from 0.86500 to 0.86650, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 45/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2836 - acc: 0.9552 - val_loss: 0.6799 - val_acc: 0.8535
#
# Epoch 00045: val_acc did not improve from 0.86650
# Epoch 46/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2772 - acc: 0.9576 - val_loss: 0.6540 - val_acc: 0.8621
#
# Epoch 00046: val_acc did not improve from 0.86650
# Epoch 47/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2857 - acc: 0.9538 - val_loss: 0.7328 - val_acc: 0.8467
#
# Epoch 00047: val_acc did not improve from 0.86650
# Epoch 48/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2824 - acc: 0.9547 - val_loss: 0.6812 - val_acc: 0.8597
#
# Epoch 00048: val_acc did not improve from 0.86650
# Epoch 49/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2776 - acc: 0.9560 - val_loss: 0.6910 - val_acc: 0.8533
#
# Epoch 00049: val_acc did not improve from 0.86650
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 50/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2598 - acc: 0.9629 - val_loss: 0.6234 - val_acc: 0.8706
#
# Epoch 00050: val_acc improved from 0.86650 to 0.87060, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 51/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2485 - acc: 0.9668 - val_loss: 0.6377 - val_acc: 0.8668
#
# Epoch 00051: val_acc did not improve from 0.87060
# Epoch 52/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2464 - acc: 0.9664 - val_loss: 0.6348 - val_acc: 0.8722
#
# Epoch 00052: val_acc improved from 0.87060 to 0.87220, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 53/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2470 - acc: 0.9652 - val_loss: 0.6417 - val_acc: 0.8653
#
# Epoch 00053: val_acc did not improve from 0.87220
# Epoch 54/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2470 - acc: 0.9647 - val_loss: 0.6466 - val_acc: 0.8665
#
# Epoch 00054: val_acc did not improve from 0.87220
# Epoch 55/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2509 - acc: 0.9639 - val_loss: 0.6265 - val_acc: 0.8700
#
# Epoch 00055: val_acc did not improve from 0.87220
# Epoch 56/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2422 - acc: 0.9662 - val_loss: 0.6416 - val_acc: 0.8697
#
# Epoch 00056: val_acc did not improve from 0.87220
# Epoch 57/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2421 - acc: 0.9660 - val_loss: 0.6437 - val_acc: 0.8672
#
# Epoch 00057: val_acc did not improve from 0.87220
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 58/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2299 - acc: 0.9693 - val_loss: 0.6313 - val_acc: 0.8744
#
# Epoch 00058: val_acc improved from 0.87220 to 0.87440, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 59/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2175 - acc: 0.9742 - val_loss: 0.6365 - val_acc: 0.8771
#
# Epoch 00059: val_acc improved from 0.87440 to 0.87710, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 60/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2178 - acc: 0.9736 - val_loss: 0.6476 - val_acc: 0.8715
#
# Epoch 00060: val_acc did not improve from 0.87710
# Epoch 61/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2165 - acc: 0.9730 - val_loss: 0.6303 - val_acc: 0.8749
#
# Epoch 00061: val_acc did not improve from 0.87710
# Epoch 62/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2162 - acc: 0.9735 - val_loss: 0.6485 - val_acc: 0.8716
#
# Epoch 00062: val_acc did not improve from 0.87710
# Epoch 63/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2119 - acc: 0.9738 - val_loss: 0.6977 - val_acc: 0.8652
#
# Epoch 00063: val_acc did not improve from 0.87710
# Epoch 64/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2146 - acc: 0.9719 - val_loss: 0.6655 - val_acc: 0.8674
#
# Epoch 00064: val_acc did not improve from 0.87710
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 65/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.2029 - acc: 0.9768 - val_loss: 0.6428 - val_acc: 0.8759
#
# Epoch 00065: val_acc did not improve from 0.87710
# Epoch 66/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1948 - acc: 0.9792 - val_loss: 0.6377 - val_acc: 0.8750
#
# Epoch 00066: val_acc did not improve from 0.87710
# Epoch 67/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1951 - acc: 0.9786 - val_loss: 0.6367 - val_acc: 0.8749
#
# Epoch 00067: val_acc did not improve from 0.87710
# Epoch 68/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1910 - acc: 0.9793 - val_loss: 0.6438 - val_acc: 0.8722
#
# Epoch 00068: val_acc did not improve from 0.87710
# Epoch 69/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1874 - acc: 0.9802 - val_loss: 0.6459 - val_acc: 0.8762
#
# Epoch 00069: val_acc did not improve from 0.87710
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 70/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1849 - acc: 0.9805 - val_loss: 0.6020 - val_acc: 0.8842
#
# Epoch 00070: val_acc improved from 0.87710 to 0.88420, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 71/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1778 - acc: 0.9826 - val_loss: 0.6231 - val_acc: 0.8789
#
# Epoch 00071: val_acc did not improve from 0.88420
# Epoch 72/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1745 - acc: 0.9835 - val_loss: 0.6166 - val_acc: 0.8787
#
# Epoch 00072: val_acc did not improve from 0.88420
# Epoch 73/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1709 - acc: 0.9836 - val_loss: 0.6312 - val_acc: 0.8785
#
# Epoch 00073: val_acc did not improve from 0.88420
# Epoch 74/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1714 - acc: 0.9833 - val_loss: 0.6331 - val_acc: 0.8803
#
# Epoch 00074: val_acc did not improve from 0.88420
# Epoch 75/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1705 - acc: 0.9834 - val_loss: 0.6222 - val_acc: 0.8794
#
# Epoch 00075: val_acc did not improve from 0.88420
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 76/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1662 - acc: 0.9846 - val_loss: 0.6305 - val_acc: 0.8801
#
# Epoch 00076: val_acc did not improve from 0.88420
# Epoch 77/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1619 - acc: 0.9857 - val_loss: 0.6270 - val_acc: 0.8821
#
# Epoch 00077: val_acc did not improve from 0.88420
# Epoch 78/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1617 - acc: 0.9850 - val_loss: 0.6492 - val_acc: 0.8807
#
# Epoch 00078: val_acc did not improve from 0.88420
# Epoch 79/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1587 - acc: 0.9865 - val_loss: 0.6470 - val_acc: 0.8823
#
# Epoch 00079: val_acc did not improve from 0.88420
# Epoch 80/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1546 - acc: 0.9870 - val_loss: 0.6390 - val_acc: 0.8802
#
# Epoch 00080: val_acc did not improve from 0.88420
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 81/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1537 - acc: 0.9867 - val_loss: 0.6404 - val_acc: 0.8801
#
# Epoch 00081: val_acc did not improve from 0.88420
# Epoch 82/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1505 - acc: 0.9879 - val_loss: 0.6372 - val_acc: 0.8833
#
# Epoch 00082: val_acc did not improve from 0.88420
# Epoch 83/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1471 - acc: 0.9881 - val_loss: 0.6249 - val_acc: 0.8812
#
# Epoch 00083: val_acc did not improve from 0.88420
# Epoch 84/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1444 - acc: 0.9893 - val_loss: 0.6338 - val_acc: 0.8783
#
# Epoch 00084: val_acc did not improve from 0.88420
# Epoch 85/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1440 - acc: 0.9887 - val_loss: 0.6279 - val_acc: 0.8838
#
# Epoch 00085: val_acc did not improve from 0.88420
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 86/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1409 - acc: 0.9894 - val_loss: 0.6132 - val_acc: 0.8846
#
# Epoch 00086: val_acc improved from 0.88420 to 0.88460, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 87/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1392 - acc: 0.9902 - val_loss: 0.6179 - val_acc: 0.8843
#
# Epoch 00087: val_acc did not improve from 0.88460
# Epoch 88/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1383 - acc: 0.9905 - val_loss: 0.6107 - val_acc: 0.8877
#
# Epoch 00088: val_acc improved from 0.88460 to 0.88770, saving model to ../content/drive/My Drive/EVA/model_before_cutout.h5
# Epoch 89/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1350 - acc: 0.9908 - val_loss: 0.6318 - val_acc: 0.8838
#
# Epoch 00089: val_acc did not improve from 0.88770
# Epoch 90/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1331 - acc: 0.9914 - val_loss: 0.6200 - val_acc: 0.8871
#
# Epoch 00090: val_acc did not improve from 0.88770
# Epoch 91/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1352 - acc: 0.9903 - val_loss: 0.6174 - val_acc: 0.8855
#
# Epoch 00091: val_acc did not improve from 0.88770
# Epoch 92/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1314 - acc: 0.9914 - val_loss: 0.6273 - val_acc: 0.8858
#
# Epoch 00092: val_acc did not improve from 0.88770
# Epoch 93/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1306 - acc: 0.9913 - val_loss: 0.6221 - val_acc: 0.8858
#
# Epoch 00093: val_acc did not improve from 0.88770
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 94/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1306 - acc: 0.9911 - val_loss: 0.6148 - val_acc: 0.8871
#
# Epoch 00094: val_acc did not improve from 0.88770
# Epoch 95/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1303 - acc: 0.9903 - val_loss: 0.6140 - val_acc: 0.8864
#
# Epoch 00095: val_acc did not improve from 0.88770
# Epoch 96/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1258 - acc: 0.9922 - val_loss: 0.6200 - val_acc: 0.8866
#
# Epoch 00096: val_acc did not improve from 0.88770
# Epoch 97/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1250 - acc: 0.9922 - val_loss: 0.6326 - val_acc: 0.8835
#
# Epoch 00097: val_acc did not improve from 0.88770
# Epoch 98/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1237 - acc: 0.9923 - val_loss: 0.6437 - val_acc: 0.8833
#
# Epoch 00098: val_acc did not improve from 0.88770
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# Epoch 99/100
# 390/390 [==============================] - 13s 32ms/step - loss: 0.1220 - acc: 0.9926 - val_loss: 0.6102 - val_acc: 0.8865
#
# Epoch 00099: val_acc did not improve from 0.88770
# Epoch 100/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1228 - acc: 0.9926 - val_loss: 0.6118 - val_acc: 0.8869
#
# Epoch 00100: val_acc did not improve from 0.88770
# Model took 1283.10 seconds to train
# Accuracy on test data is: 85.16

# %%
model =keras.models.load_model('../content/drive/My Drive/EVA/model_before_cutout.h5')

# %%
score = model.evaluate(test_features, test_labels, batch_size=128)
print (score[1])
# Out:
# 10000/10000 [==============================] - 2s 241us/step
# 0.8877

# %%
import cv2
from google.colab.patches import cv2_imshow

(trainX, trainy), (testX, testy) = cifar10.load_data()

images = [1,101,201,501,901,1001,1501,1601,2001,4001,5001,6001,7001,8001,9001,9999]
for j in images:
  x = testX[j]
  x = np.expand_dims(x, axis=0)
  preds = model.predict(x,batch_size=1)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_65")

  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(256):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
  
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  img = (testX[j])
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  #cv2_imshow(img)
  #cv2_imshow(superimposed_img)
  concatimg = cv2.hconcat([img,superimposed_img])
  # Display the concatenated image
  print (j)
  cv2_imshow(concatimg)
  cv2.waitKey(0)
  print (" ")
  j = j + 1
# Out:
# 1
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DD321D0>
#
# 101
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DD32128>
#
# 201
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DC28F60>
#
# 501
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DD322B0>
#
# 901
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DD32208>
#
# 1001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DD322B0>
#
# 1501
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DB8E7B8>
#
# 1601
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DA64748>
#
# 2001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DAF6588>
#
# 4001
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D939B38>
#
# 5001
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715DB23C88>
#
# 6001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D6F8F28>
#
# 7001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D533550>
#
# 8001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D60C358>
#
# 9001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D5F5C88>
#
# 9999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D415EB8>

# %%
# Define model again and use cutout
from keras import regularizers
# Define the model
model1 = Sequential()
model1.add(Convolution2D(32, 3, 3, border_mode='same',kernel_regularizer=regularizers.l2(0.0001), input_shape=(32, 32, 3)))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.2))

model1.add(Convolution2D(32, 1, 1))

model1.add(Convolution2D(64, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001),border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.3))

model1.add(Convolution2D(32, 1, 1))

model1.add(Convolution2D(128, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(Convolution2D(256, 3, 3,kernel_regularizer=regularizers.l2(0.0001), border_mode='same'))
model1.add(Activation('relu'))
model1.add(BatchNormalization())

model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.5))

model1.add(Convolution2D(10, 1, 1))

model1.add(AveragePooling2D(pool_size = (4,4)))
model1.add(Flatten())

model1.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), kernel_regularizer=<keras.reg..., input_shape=(32, 32, 3..., padding="same")`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), kernel_regularizer=<keras.reg..., padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_67 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_50 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_51 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_52 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_53 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 8, 8, 32)          4128
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 8, 8, 128)         36992
# _________________________________________________________________
# activation_54 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_55 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 4, 4, 10)          2570
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_56 (Activation)   (None, 10)                0
# =================================================================
# Total params: 455,370
# Trainable params: 454,026
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau

checkpointer1 = ModelCheckpoint(filepath='../content/drive/My Drive/EVA/model_after_cutout.h5', monitor='val_acc', mode='auto', verbose = 1, save_best_only=True)
lr_reducer1 = ReduceLROnPlateau(monitor='val_acc',factor=0.8, cooldown=0, patience=5, min_lr=0.5e-9,verbose = 1)



# Compile the model
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %% [markdown]
# **Model with Cutout**

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False,
                             preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=True))


# train the model
start = time.time()
# Train the model
model_info = model1.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), callbacks=[checkpointer1,lr_reducer1],verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model1))
# Out:
# Epoch 1/100
#   3/390 [..............................] - ETA: 17s - loss: 0.2215 - acc: 0.9635
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2373 - acc: 0.9582 - val_loss: 0.5090 - val_acc: 0.8943
#
# Epoch 00001: val_acc did not improve from 0.89540
# Epoch 2/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2316 - acc: 0.9593 - val_loss: 0.5107 - val_acc: 0.8953
#
# Epoch 00002: val_acc did not improve from 0.89540
# Epoch 3/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2346 - acc: 0.9581 - val_loss: 0.5105 - val_acc: 0.8953
#
# Epoch 00003: val_acc did not improve from 0.89540
# Epoch 4/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2335 - acc: 0.9589 - val_loss: 0.5086 - val_acc: 0.8956
#
# Epoch 00004: val_acc improved from 0.89540 to 0.89560, saving model to ../content/drive/My Drive/EVA/model_after_cutout.h5
# Epoch 5/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2325 - acc: 0.9591 - val_loss: 0.5184 - val_acc: 0.8907
#
# Epoch 00005: val_acc did not improve from 0.89560
# Epoch 6/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2319 - acc: 0.9590 - val_loss: 0.4939 - val_acc: 0.8975
#
# Epoch 00006: val_acc improved from 0.89560 to 0.89750, saving model to ../content/drive/My Drive/EVA/model_after_cutout.h5
# Epoch 7/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2301 - acc: 0.9599 - val_loss: 0.5067 - val_acc: 0.8936
#
# Epoch 00007: val_acc did not improve from 0.89750
# Epoch 8/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2279 - acc: 0.9595 - val_loss: 0.5100 - val_acc: 0.8928
#
# Epoch 00008: val_acc did not improve from 0.89750
# Epoch 9/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2284 - acc: 0.9601 - val_loss: 0.5125 - val_acc: 0.8958
#
# Epoch 00009: val_acc did not improve from 0.89750
# Epoch 10/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2228 - acc: 0.9611 - val_loss: 0.5030 - val_acc: 0.8935
#
# Epoch 00010: val_acc did not improve from 0.89750
# Epoch 11/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2254 - acc: 0.9604 - val_loss: 0.5120 - val_acc: 0.8934
#
# Epoch 00011: val_acc did not improve from 0.89750
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 12/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2216 - acc: 0.9615 - val_loss: 0.5082 - val_acc: 0.8958
#
# Epoch 00012: val_acc did not improve from 0.89750
# Epoch 13/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2215 - acc: 0.9616 - val_loss: 0.5047 - val_acc: 0.8958
#
# Epoch 00013: val_acc did not improve from 0.89750
# Epoch 14/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2179 - acc: 0.9623 - val_loss: 0.5091 - val_acc: 0.8959
#
# Epoch 00014: val_acc did not improve from 0.89750
# Epoch 15/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2191 - acc: 0.9617 - val_loss: 0.5023 - val_acc: 0.8931
#
# Epoch 00015: val_acc did not improve from 0.89750
# Epoch 16/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2133 - acc: 0.9638 - val_loss: 0.5148 - val_acc: 0.8922
#
# Epoch 00016: val_acc did not improve from 0.89750
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# Epoch 17/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2138 - acc: 0.9641 - val_loss: 0.5030 - val_acc: 0.8944
#
# Epoch 00017: val_acc did not improve from 0.89750
# Epoch 18/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2120 - acc: 0.9635 - val_loss: 0.5023 - val_acc: 0.8964
#
# Epoch 00018: val_acc did not improve from 0.89750
# Epoch 19/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2100 - acc: 0.9643 - val_loss: 0.5025 - val_acc: 0.8948
#
# Epoch 00019: val_acc did not improve from 0.89750
# Epoch 20/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2139 - acc: 0.9631 - val_loss: 0.4951 - val_acc: 0.8960
#
# Epoch 00020: val_acc did not improve from 0.89750
# Epoch 21/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2114 - acc: 0.9632 - val_loss: 0.5039 - val_acc: 0.8965
#
# Epoch 00021: val_acc did not improve from 0.89750
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# Epoch 22/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2079 - acc: 0.9645 - val_loss: 0.4996 - val_acc: 0.8957
#
# Epoch 00022: val_acc did not improve from 0.89750
# Epoch 23/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2093 - acc: 0.9637 - val_loss: 0.5067 - val_acc: 0.8954
#
# Epoch 00023: val_acc did not improve from 0.89750
# Epoch 24/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2076 - acc: 0.9649 - val_loss: 0.4963 - val_acc: 0.8965
#
# Epoch 00024: val_acc did not improve from 0.89750
# Epoch 25/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2070 - acc: 0.9638 - val_loss: 0.4983 - val_acc: 0.8957
#
# Epoch 00025: val_acc did not improve from 0.89750
# Epoch 26/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2034 - acc: 0.9658 - val_loss: 0.5027 - val_acc: 0.8953
#
# Epoch 00026: val_acc did not improve from 0.89750
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# Epoch 27/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2044 - acc: 0.9647 - val_loss: 0.4926 - val_acc: 0.8971
#
# Epoch 00027: val_acc did not improve from 0.89750
# Epoch 28/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2048 - acc: 0.9649 - val_loss: 0.5007 - val_acc: 0.8982
#
# Epoch 00028: val_acc improved from 0.89750 to 0.89820, saving model to ../content/drive/My Drive/EVA/model_after_cutout.h5
# Epoch 29/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2003 - acc: 0.9665 - val_loss: 0.5106 - val_acc: 0.8954
#
# Epoch 00029: val_acc did not improve from 0.89820
# Epoch 30/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2017 - acc: 0.9664 - val_loss: 0.4906 - val_acc: 0.8965
#
# Epoch 00030: val_acc did not improve from 0.89820
# Epoch 31/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2033 - acc: 0.9646 - val_loss: 0.4971 - val_acc: 0.8956
#
# Epoch 00031: val_acc did not improve from 0.89820
# Epoch 32/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.2000 - acc: 0.9666 - val_loss: 0.4980 - val_acc: 0.8963
#
# Epoch 00032: val_acc did not improve from 0.89820
# Epoch 33/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1968 - acc: 0.9671 - val_loss: 0.4944 - val_acc: 0.8950
#
# Epoch 00033: val_acc did not improve from 0.89820
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# Epoch 34/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1944 - acc: 0.9678 - val_loss: 0.4936 - val_acc: 0.8968
#
# Epoch 00034: val_acc did not improve from 0.89820
# Epoch 35/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1964 - acc: 0.9670 - val_loss: 0.4936 - val_acc: 0.8960
#
# Epoch 00035: val_acc did not improve from 0.89820
# Epoch 36/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1993 - acc: 0.9664 - val_loss: 0.4890 - val_acc: 0.8972
#
# Epoch 00036: val_acc did not improve from 0.89820
# Epoch 37/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1981 - acc: 0.9667 - val_loss: 0.4925 - val_acc: 0.8966
#
# Epoch 00037: val_acc did not improve from 0.89820
# Epoch 38/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1960 - acc: 0.9672 - val_loss: 0.4926 - val_acc: 0.8981
#
# Epoch 00038: val_acc did not improve from 0.89820
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# Epoch 39/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1944 - acc: 0.9677 - val_loss: 0.4905 - val_acc: 0.8979
#
# Epoch 00039: val_acc did not improve from 0.89820
# Epoch 40/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1936 - acc: 0.9685 - val_loss: 0.4944 - val_acc: 0.8980
#
# Epoch 00040: val_acc did not improve from 0.89820
# Epoch 41/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1971 - acc: 0.9671 - val_loss: 0.4924 - val_acc: 0.8988
#
# Epoch 00041: val_acc improved from 0.89820 to 0.89880, saving model to ../content/drive/My Drive/EVA/model_after_cutout.h5
# Epoch 42/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1921 - acc: 0.9677 - val_loss: 0.4895 - val_acc: 0.8970
#
# Epoch 00042: val_acc did not improve from 0.89880
# Epoch 43/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1923 - acc: 0.9674 - val_loss: 0.5003 - val_acc: 0.8963
#
# Epoch 00043: val_acc did not improve from 0.89880
# Epoch 44/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1919 - acc: 0.9683 - val_loss: 0.4906 - val_acc: 0.8967
#
# Epoch 00044: val_acc did not improve from 0.89880
# Epoch 45/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1938 - acc: 0.9676 - val_loss: 0.4980 - val_acc: 0.8983
#
# Epoch 00045: val_acc did not improve from 0.89880
# Epoch 46/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1896 - acc: 0.9686 - val_loss: 0.4931 - val_acc: 0.8970
#
# Epoch 00046: val_acc did not improve from 0.89880
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# Epoch 47/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1902 - acc: 0.9688 - val_loss: 0.4907 - val_acc: 0.8974
#
# Epoch 00047: val_acc did not improve from 0.89880
# Epoch 48/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1906 - acc: 0.9684 - val_loss: 0.4895 - val_acc: 0.8984
#
# Epoch 00048: val_acc did not improve from 0.89880
# Epoch 49/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1890 - acc: 0.9695 - val_loss: 0.4917 - val_acc: 0.8992
#
# Epoch 00049: val_acc improved from 0.89880 to 0.89920, saving model to ../content/drive/My Drive/EVA/model_after_cutout.h5
# Epoch 50/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1891 - acc: 0.9698 - val_loss: 0.4969 - val_acc: 0.8982
#
# Epoch 00050: val_acc did not improve from 0.89920
# Epoch 51/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1901 - acc: 0.9690 - val_loss: 0.4936 - val_acc: 0.8979
#
# Epoch 00051: val_acc did not improve from 0.89920
# Epoch 52/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1857 - acc: 0.9703 - val_loss: 0.4933 - val_acc: 0.9001
#
# Epoch 00052: val_acc improved from 0.89920 to 0.90010, saving model to ../content/drive/My Drive/EVA/model_after_cutout.h5
# Epoch 53/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1871 - acc: 0.9697 - val_loss: 0.4900 - val_acc: 0.8985
#
# Epoch 00053: val_acc did not improve from 0.90010
# Epoch 54/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1857 - acc: 0.9699 - val_loss: 0.4957 - val_acc: 0.8981
#
# Epoch 00054: val_acc did not improve from 0.90010
# Epoch 55/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1857 - acc: 0.9700 - val_loss: 0.4903 - val_acc: 0.8976
#
# Epoch 00055: val_acc did not improve from 0.90010
# Epoch 56/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1839 - acc: 0.9705 - val_loss: 0.4919 - val_acc: 0.8977
#
# Epoch 00056: val_acc did not improve from 0.90010
# Epoch 57/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1864 - acc: 0.9700 - val_loss: 0.4930 - val_acc: 0.8983
#
# Epoch 00057: val_acc did not improve from 0.90010
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
# Epoch 58/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1869 - acc: 0.9690 - val_loss: 0.4911 - val_acc: 0.8988
#
# Epoch 00058: val_acc did not improve from 0.90010
# Epoch 59/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1842 - acc: 0.9695 - val_loss: 0.4948 - val_acc: 0.8979
#
# Epoch 00059: val_acc did not improve from 0.90010
# Epoch 60/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1854 - acc: 0.9710 - val_loss: 0.4915 - val_acc: 0.8986
#
# Epoch 00060: val_acc did not improve from 0.90010
# Epoch 61/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1839 - acc: 0.9700 - val_loss: 0.4925 - val_acc: 0.8984
#
# Epoch 00061: val_acc did not improve from 0.90010
# Epoch 62/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1858 - acc: 0.9694 - val_loss: 0.4890 - val_acc: 0.8973
#
# Epoch 00062: val_acc did not improve from 0.90010
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
# Epoch 63/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1833 - acc: 0.9704 - val_loss: 0.4924 - val_acc: 0.8986
#
# Epoch 00063: val_acc did not improve from 0.90010
# Epoch 64/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1833 - acc: 0.9708 - val_loss: 0.4898 - val_acc: 0.8987
#
# Epoch 00064: val_acc did not improve from 0.90010
# Epoch 65/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1835 - acc: 0.9702 - val_loss: 0.4898 - val_acc: 0.8976
#
# Epoch 00065: val_acc did not improve from 0.90010
# Epoch 66/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1836 - acc: 0.9697 - val_loss: 0.4901 - val_acc: 0.8987
#
# Epoch 00066: val_acc did not improve from 0.90010
# Epoch 67/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1819 - acc: 0.9712 - val_loss: 0.4882 - val_acc: 0.8996
#
# Epoch 00067: val_acc did not improve from 0.90010
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
# Epoch 68/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1833 - acc: 0.9707 - val_loss: 0.4889 - val_acc: 0.8994
#
# Epoch 00068: val_acc did not improve from 0.90010
# Epoch 69/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1855 - acc: 0.9698 - val_loss: 0.4864 - val_acc: 0.8994
#
# Epoch 00069: val_acc did not improve from 0.90010
# Epoch 70/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1858 - acc: 0.9696 - val_loss: 0.4888 - val_acc: 0.8985
#
# Epoch 00070: val_acc did not improve from 0.90010
# Epoch 71/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1824 - acc: 0.9706 - val_loss: 0.4885 - val_acc: 0.8985
#
# Epoch 00071: val_acc did not improve from 0.90010
# Epoch 72/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1821 - acc: 0.9706 - val_loss: 0.4897 - val_acc: 0.8982
#
# Epoch 00072: val_acc did not improve from 0.90010
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
# Epoch 73/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1825 - acc: 0.9706 - val_loss: 0.4891 - val_acc: 0.8985
#
# Epoch 00073: val_acc did not improve from 0.90010
# Epoch 74/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1830 - acc: 0.9706 - val_loss: 0.4881 - val_acc: 0.8988
#
# Epoch 00074: val_acc did not improve from 0.90010
# Epoch 75/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1829 - acc: 0.9709 - val_loss: 0.4893 - val_acc: 0.8992
#
# Epoch 00075: val_acc did not improve from 0.90010
# Epoch 76/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1836 - acc: 0.9700 - val_loss: 0.4880 - val_acc: 0.8998
#
# Epoch 00076: val_acc did not improve from 0.90010
# Epoch 77/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1815 - acc: 0.9716 - val_loss: 0.4901 - val_acc: 0.8989
#
# Epoch 00077: val_acc did not improve from 0.90010
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
# Epoch 78/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1799 - acc: 0.9710 - val_loss: 0.4912 - val_acc: 0.8988
#
# Epoch 00078: val_acc did not improve from 0.90010
# Epoch 79/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1824 - acc: 0.9704 - val_loss: 0.4901 - val_acc: 0.8987
#
# Epoch 00079: val_acc did not improve from 0.90010
# Epoch 80/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1806 - acc: 0.9709 - val_loss: 0.4894 - val_acc: 0.8980
#
# Epoch 00080: val_acc did not improve from 0.90010
# Epoch 81/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1810 - acc: 0.9708 - val_loss: 0.4878 - val_acc: 0.8979
#
# Epoch 00081: val_acc did not improve from 0.90010
# Epoch 82/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1807 - acc: 0.9710 - val_loss: 0.4889 - val_acc: 0.8995
#
# Epoch 00082: val_acc did not improve from 0.90010
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
# Epoch 83/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1824 - acc: 0.9704 - val_loss: 0.4888 - val_acc: 0.8991
#
# Epoch 00083: val_acc did not improve from 0.90010
# Epoch 84/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1800 - acc: 0.9709 - val_loss: 0.4867 - val_acc: 0.8986
#
# Epoch 00084: val_acc did not improve from 0.90010
# Epoch 85/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1802 - acc: 0.9711 - val_loss: 0.4883 - val_acc: 0.8984
#
# Epoch 00085: val_acc did not improve from 0.90010
# Epoch 86/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1806 - acc: 0.9710 - val_loss: 0.4894 - val_acc: 0.8988
#
# Epoch 00086: val_acc did not improve from 0.90010
# Epoch 87/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1819 - acc: 0.9690 - val_loss: 0.4871 - val_acc: 0.8985
#
# Epoch 00087: val_acc did not improve from 0.90010
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 5.902958946535364e-06.
# Epoch 88/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1800 - acc: 0.9710 - val_loss: 0.4866 - val_acc: 0.8985
#
# Epoch 00088: val_acc did not improve from 0.90010
# Epoch 89/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1795 - acc: 0.9709 - val_loss: 0.4859 - val_acc: 0.8987
#
# Epoch 00089: val_acc did not improve from 0.90010
# Epoch 90/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1786 - acc: 0.9713 - val_loss: 0.4877 - val_acc: 0.8981
#
# Epoch 00090: val_acc did not improve from 0.90010
# Epoch 91/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1770 - acc: 0.9718 - val_loss: 0.4881 - val_acc: 0.8977
#
# Epoch 00091: val_acc did not improve from 0.90010
# Epoch 92/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1801 - acc: 0.9711 - val_loss: 0.4862 - val_acc: 0.8990
#
# Epoch 00092: val_acc did not improve from 0.90010
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 4.7223671572282915e-06.
# Epoch 93/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1790 - acc: 0.9713 - val_loss: 0.4871 - val_acc: 0.8975
#
# Epoch 00093: val_acc did not improve from 0.90010
# Epoch 94/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1782 - acc: 0.9718 - val_loss: 0.4870 - val_acc: 0.8989
#
# Epoch 00094: val_acc did not improve from 0.90010
# Epoch 95/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1813 - acc: 0.9701 - val_loss: 0.4879 - val_acc: 0.8986
#
# Epoch 00095: val_acc did not improve from 0.90010
# Epoch 96/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1807 - acc: 0.9711 - val_loss: 0.4862 - val_acc: 0.8984
#
# Epoch 00096: val_acc did not improve from 0.90010
# Epoch 97/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1806 - acc: 0.9713 - val_loss: 0.4869 - val_acc: 0.8982
#
# Epoch 00097: val_acc did not improve from 0.90010
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 3.7778936530230567e-06.
# Epoch 98/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1789 - acc: 0.9716 - val_loss: 0.4860 - val_acc: 0.8981
#
# Epoch 00098: val_acc did not improve from 0.90010
# Epoch 99/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1787 - acc: 0.9716 - val_loss: 0.4870 - val_acc: 0.8989
#
# Epoch 00099: val_acc did not improve from 0.90010
# Epoch 100/100
# 390/390 [==============================] - 13s 33ms/step - loss: 0.1806 - acc: 0.9712 - val_loss: 0.4864 - val_acc: 0.8983
#
# Epoch 00100: val_acc did not improve from 0.90010
# Model took 1298.32 seconds to train
# Accuracy on test data is: 89.83

# %%
model=keras.models.load_model('../content/drive/My Drive/EVA/model_after_cutout.h5')

# %%
score = model.evaluate(test_features, test_labels, batch_size=128)
print (score[1])
# Out:
# 10000/10000 [==============================] - 3s 313us/step
# 0.9001

# %% [markdown]
# ***Model with Cutout : Grad CAM results ***

# %%
import cv2
from google.colab.patches import cv2_imshow

images = [1,101,201,501,901,1001,1501,1601,2001,4001,5001,6001,7001,8001,9001,9999]
for j in images:
  x = testX[j]
  x = np.expand_dims(x, axis=0)
  preds = model.predict(x,batch_size=1)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_74")

  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(256):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
  
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap) 
  img = (testX[j])
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  #cv2_imshow(img)
  #cv2_imshow(superimposed_img)
  concatimg = cv2.hconcat([img,superimposed_img])
  # Display the concatenated image
  print (j)
  cv2_imshow(concatimg)
  cv2.waitKey(0)
  print (" ")
  j = j + 1
# Out:
# 1
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715D401940>
#
# 101
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157E8BF98>
#
# 201
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7158EC0048>
#
# 501
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157CEAF98>
#
# 901
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7158EC00B8>
#
# 1001
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157DB0E80>
#
# 1501
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157F68F98>
#
# 1601
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157B8F5C0>
#
# 2001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F71579C8978>
#
# 4001
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157AB57B8>
#
# 5001
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F71577E9F28>
#
# 6001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F71579B1E48>
#
# 7001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F71578D6F60>
#
# 8001
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F7157817D68>
#
# 9001
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F715787FCC0>
#
# 9999
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=64x32 at 0x7F71599FDCF8>
